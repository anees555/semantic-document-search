# %%
import chromadb

print(chromadb.__version__)
# Out:
# 1.3.7

# %% [markdown]
# ### Create client

# %%
chroma_client = chromadb.Client()

chroma_client

# %% [markdown]
# ### Create collection
# * collections are where we store our embeddings, documents and any additional metadata

# %%
collection = chroma_client.create_collection(name = "First_collection",
                                             metadata={"title": "random documents",
                                                       
                                            "description": "This store contains the embeddings of random string"})
collection
# Out:
# Collection(name=First_collection)

# %%
collection.metadata
# Out:
# {'description': 'This store contains the embeddings of random string',
#  'title': 'random documents'}

# %%
collection.name
# Out:
# 'First_collection'

# %% [markdown]
# ### We can use modify() method to modify the name and metadata of the collection we have created

# %%
collection.modify(name="First_modified_collection",
                  metadata={
                      "description": "This store contains the random string (modified)",
                      'title': "random documents (modified)"
                  })

# %%
collection.name, collection.metadata
# Out:
# ('First_modified_collection',
#  {'description': 'This store contains the random string (modified)',
#   'title': 'random documents (modified)'})

# %% [markdown]
# ### Add documents to collection

# %%
docs = [
    "Claude 4.5 is latest conversational AI model from Anthropic.",
    "Gemini is latest conversational AI model from google.",
    "Llama-4 is latest conversational AI model from Meta.",
    "Mixtral 8x7B is latest conversational AI model from Mistral AI.",
    "GPT-5 is latest conversational AI model from OpenAI"
]

collection.add(
    documents=docs,
    ids = ["anthropic", "google", "meta", "mistral", "openai"],
    metadatas=[{"version": 4.5}, {"version": 3}, {"version": 4}, {"version": 2}, {"version": 5}]
)
# Out:
# C:\Users\Lenovo\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:12<00:00, 6.68MiB/s]

# %% [markdown]
# * embeddings: The embedding s to add. If None, embedding will be computed based on the documents or images using the embedding_functions set for the collection. optional
# * metadatas: The metadata to associate with the embeddings. When querying. YOu can filter on this metadata. optional
# * documents: The documents to associate with the embeddings. optional
# * images: The images to associate with the embeddings. optional
# * uris: The uris of the images to associate with the embeddings. Optional

# %%
collection.count()
# Out:
# 5

# %%
collection.get(ids=['anthropic', 'openai'])
# Out:
# {'ids': ['anthropic', 'openai'],
#  'embeddings': None,
#  'documents': ['Claude 4.5 is latest conversational AI model from Anthropic.',
#   'GPT-5 is latest conversational AI model from OpenAI'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'version': 4.5}, {'version': 5}]}

# %% [markdown]
# * include() :-> what fields to include in result. Default is ['documents', 'metadatas']

# %%
result = collection.get(ids=['anthropic', 'openai'], include=['embeddings', 'documents'])

# %%
result
# Out:
# {'ids': ['anthropic', 'openai'],
#  'embeddings': array([[ 8.84437840e-03, -1.74004920e-02,  3.94670758e-04,
#          -1.40978023e-03,  3.81029211e-02,  1.25021103e-03,
#           3.79684567e-02,  1.46647310e-02,  6.99088955e-03,
#           1.76980924e-02, -2.36694794e-02, -1.79002751e-02,
#          -9.04824287e-02,  2.53535882e-02,  2.34696325e-02,
#           3.05134766e-02,  1.16425231e-02, -2.79733371e-02,
#          -8.66195112e-02, -4.14507240e-02, -1.02093639e-02,
#           1.12054832e-02,  4.51803245e-02, -2.50555971e-03,
#          -4.33832668e-02, -4.37491909e-02, -6.64262474e-03,
#          -8.30394477e-02,  5.00220284e-02, -7.41148228e-03,
#           3.42607461e-02,  8.40155631e-02,  6.30196929e-02,
#          -1.35988444e-02, -8.93824920e-02,  2.67263632e-02,
#          -1.14643248e-02, -2.48200893e-02, -1.42621167e-03,
#           4.70247716e-02, -2.13839952e-02, -5.04222959e-02,
#          -5.14766723e-02, -2.06556451e-02,  8.03897902e-02,
#           3.15873623e-02, -5.92645854e-02, -1.63625907e-02,
#           4.87964600e-02, -6.69252500e-03, -1.85746968e-01,
#          -1.18497936e-02, -6.99090166e-03, -1.45269278e-02,
#           1.68164968e-02, -1.64721143e-02, -1.33270361e-02,
#          -1.37279201e-02,  3.97750810e-02, -1.34551330e-02,
#           4.12458666e-02, -2.76134349e-02,  1.95669550e-02,
#           6.54457361e-02,  5.27830683e-02,  6.52485564e-02,
#          -5.80738224e-02, -1.36172222e-02, -3.44910286e-02,
#           9.77632217e-03, -3.19528691e-02, -5.29332794e-02,
#          -1.13940211e-02, -1.85825732e-02,  1.07743563e-02,
#          -2.05270015e-02,  2.91340258e-02, -6.75689578e-02,
#           9.88431349e-02, -5.86733259e-02, -1.08691305e-02,
#          -7.31011704e-02,  1.46212969e-02, -4.14568484e-02,
#           6.46608416e-03,  3.05413119e-02, -2.34105047e-02,
#          -3.67972963e-02,  1.90092623e-02, -2.60315929e-02,
#          -6.26937896e-02, -6.24051616e-02,  3.55319977e-02,
#           2.90718656e-02,  2.29116920e-02,  1.16899446e-01,
#          -3.08124889e-02, -5.43444194e-02, -3.17002274e-02,
#           6.09490760e-02, -4.96353656e-02, -3.05911265e-02,
#           3.17512043e-02, -5.52836573e-03,  7.96565320e-03,
#          -2.24658102e-02,  1.02635071e-01, -1.05015598e-02,
#          -1.46030895e-02,  4.56378795e-03, -8.00781474e-02,
#          -1.46050006e-02,  2.40565669e-02,  1.01218671e-02,
#           1.05767116e-01, -1.68565363e-02,  4.70738066e-03,
#           4.10579033e-02,  5.03390767e-02, -5.39924297e-03,
#           3.83947231e-02,  1.87455621e-02,  7.89890438e-03,
#           9.80569646e-02,  3.78982127e-02, -1.09542767e-02,
#          -1.58646461e-02, -1.15273972e-33,  1.13782929e-02,
#           4.43535447e-02,  1.58016264e-01,  6.78826720e-02,
#           3.24505456e-02,  8.34713411e-03, -1.49248703e-03,
#           2.54342109e-02,  7.82293454e-03,  2.99089774e-02,
#          -7.13307932e-02, -4.46672514e-02,  1.12070898e-02,
#           8.63625631e-02, -6.18263222e-02, -1.39555298e-02,
#          -8.30304474e-02,  3.52252573e-02,  2.72484627e-02,
#          -1.19257243e-02,  6.98168576e-02,  5.39686233e-02,
#          -3.63087002e-03,  4.99586947e-02,  9.62794051e-02,
#           9.28747728e-02,  6.05035834e-02, -9.23763663e-02,
#           6.39905483e-02,  1.53600890e-02, -1.13310367e-01,
#           8.55972990e-02, -8.41719583e-02,  6.53337361e-03,
#           4.19803709e-03,  3.50194350e-02, -4.43733446e-02,
#          -2.70432476e-02, -2.99242865e-02,  4.66383100e-02,
#           5.37384748e-02,  5.65999467e-03,  1.35967247e-02,
#          -7.41847306e-02, -5.19882329e-02,  5.26670441e-02,
#          -2.86370814e-02,  5.26427943e-03, -9.95577034e-03,
#          -2.36922055e-02, -4.70706932e-02,  3.49786878e-02,
#           2.17760708e-02, -3.62833999e-02,  2.25424096e-02,
#          -8.47172514e-02, -1.07653085e-02,  3.16704214e-02,
#          -1.67072266e-02, -2.62023159e-03,  7.67460689e-02,
#           4.98431623e-02, -2.72363797e-03,  2.72847805e-03,
#           8.31987038e-02,  3.61827537e-02, -1.03505529e-01,
#          -1.05941510e-02,  7.60656223e-02, -1.46887945e-02,
#          -6.49608998e-03,  6.04616338e-03,  1.11167543e-02,
#           1.71598850e-03,  1.24267507e-02,  2.20588632e-02,
#          -4.52256948e-02, -9.26794186e-02,  3.01675126e-02,
#           1.22416613e-03, -1.04433767e-01,  1.95077900e-02,
#          -2.97553744e-02,  1.08649414e-02,  3.77649814e-02,
#          -4.08799760e-02,  7.82944821e-03, -1.65437572e-02,
#           4.80445437e-02,  3.70740518e-03, -8.84376839e-03,
#          -5.75750358e-02, -6.59880461e-03,  1.08540840e-01,
#          -8.32492635e-02, -7.33306161e-34, -5.52791059e-02,
#          -5.36839664e-03, -6.86500221e-02,  6.90761581e-02,
#           5.02692834e-02, -4.67811376e-02,  7.54159642e-04,
#           4.85695861e-02,  9.10007302e-03,  7.33887963e-03,
#           9.74759981e-02, -6.65690452e-02,  8.71760771e-02,
#           1.59163456e-02,  1.35470986e-01,  3.68131399e-02,
#          -2.73077935e-02, -1.20748959e-01,  2.99558844e-02,
#           8.32166597e-02,  2.93653701e-02,  5.02247596e-04,
#          -1.21312238e-01, -2.85549350e-02,  1.85835164e-03,
#           4.19745594e-03,  5.20347469e-02,  2.67756004e-02,
#           2.53484566e-02, -3.72134000e-02, -1.22032382e-01,
#          -1.51583431e-02, -6.55059293e-02,  4.14410867e-02,
#           2.09243651e-02,  9.03356075e-02, -4.22781296e-02,
#          -3.06676980e-02, -2.65964158e-02,  3.82640236e-03,
#           5.24602905e-02, -6.55188318e-03, -8.29757228e-02,
#           3.54961939e-02,  3.14093642e-02, -2.35613417e-02,
#          -3.83450761e-02,  3.93266939e-02, -4.81655337e-02,
#          -1.12991491e-02,  5.87738492e-02, -3.49915400e-02,
#          -4.75040004e-02, -1.19964689e-01, -1.07076988e-01,
#           3.74694057e-02,  3.65689918e-02, -1.42332716e-02,
#          -1.82660501e-02,  1.45167476e-02, -4.94961180e-02,
#          -4.47991006e-02,  8.65102261e-02, -1.36549538e-02,
#          -1.14906800e-03,  2.67438125e-02, -4.83189113e-02,
#           6.79496825e-02, -3.10383812e-02, -5.28560057e-02,
#           8.83567631e-02, -2.75037494e-02, -5.21654673e-02,
#           4.13565673e-02, -1.98669787e-02,  2.87069604e-02,
#           5.24751795e-03, -2.96734329e-02,  2.14150976e-02,
#          -6.67644367e-02, -8.22491348e-02, -7.90394768e-02,
#           9.69420150e-02,  8.64233449e-02,  3.23171564e-03,
#           5.66980876e-02, -3.64669152e-02,  1.88010242e-02,
#           3.11771259e-02,  4.44579646e-02, -9.02587082e-03,
#          -2.45631300e-03, -4.25080359e-02,  8.14768374e-02,
#          -9.69270244e-02, -2.03898924e-08, -2.14374047e-02,
#           1.57278273e-02,  6.52901530e-02,  1.44969299e-02,
#           6.14064150e-02,  4.06612530e-02, -3.54773216e-02,
#          -2.07159072e-02, -5.38336001e-02,  2.35694908e-02,
#          -1.66389719e-02,  7.44934240e-03,  8.76833722e-02,
#           3.22160944e-02,  9.30895358e-02,  3.49450670e-02,
#          -1.53675759e-02, -4.52767760e-02,  1.04714679e-02,
#          -7.50738308e-02,  7.78433457e-02, -1.78257599e-02,
#          -2.41557732e-02, -9.08293482e-03, -3.14191543e-03,
#          -5.44035323e-02, -5.15750200e-02, -2.28826273e-02,
#          -9.10691097e-02,  1.51876677e-02,  1.36442215e-03,
#           7.24142194e-02, -2.78011058e-02, -2.60719806e-02,
#           7.90126696e-02,  2.85859089e-02, -1.42432284e-02,
#          -8.91629681e-02, -3.15674916e-02,  8.89391080e-03,
#          -1.94708481e-02,  5.16682081e-02, -5.14613092e-02,
#          -1.84793789e-02,  1.37639821e-01,  9.58717056e-03,
#          -9.48609784e-03, -2.05830380e-01,  5.07997833e-02,
#          -4.38537821e-03, -6.84933588e-02,  3.08799986e-02,
#          -1.21975625e-02,  3.43754031e-02,  8.83965641e-02,
#           2.68217139e-02, -6.73051700e-02, -3.48749794e-02,
#          -2.21507307e-02,  3.36472765e-02,  1.92760881e-02,
#           6.24958947e-02, -3.61666456e-02, -5.50591610e-02],
#         [-7.01094195e-02, -1.01400398e-01,  1.03456145e-02,
#           3.05133648e-02,  1.12953097e-01, -7.99233317e-02,
#           5.32378107e-02, -5.39123639e-03,  3.03694624e-02,
#          -3.67817953e-02, -7.82332644e-02, -2.91501684e-03,
#          -5.29730096e-02,  2.84914151e-02,  5.86133301e-02,
#           3.53312753e-02,  3.84261087e-02, -2.22604908e-02,
#          -9.50123519e-02, -8.73335451e-02,  1.66870153e-03,
#           1.14265151e-01,  6.34254813e-02, -1.77752879e-02,
#           1.84637606e-02,  1.02101481e-02,  5.59507906e-02,
#          -7.11850673e-02,  7.47690396e-03,  1.67850293e-02,
#           2.17760708e-02,  1.08726695e-02,  3.57364602e-02,
#           5.04364669e-02, -1.23462930e-01,  5.83133847e-02,
#          -7.90279955e-02, -4.06173579e-02,  1.05686253e-02,
#          -7.76467612e-03, -1.33489510e-02, -4.71077748e-02,
#          -9.14357044e-03, -1.83503814e-02,  1.07108772e-01,
#          -4.97169197e-02, -8.62225816e-02, -2.74904519e-02,
#           2.89789196e-02,  1.43562509e-02, -1.29834309e-01,
#          -3.29076611e-02,  3.60856368e-03,  3.08860838e-02,
#           1.41372550e-02,  6.91189542e-02, -3.26208994e-02,
#          -1.92712285e-02,  3.62601690e-02, -2.98990775e-02,
#           6.31518960e-02, -5.70396893e-02, -6.91507682e-02,
#           6.60596974e-03, -2.39882078e-02,  7.55777583e-02,
#          -1.32359108e-02, -2.50613932e-02,  1.42316334e-02,
#          -7.37923980e-02,  3.77600268e-02,  7.63893574e-02,
#          -4.81645465e-02, -3.32330801e-02, -3.37077677e-02,
#           6.26189932e-02,  1.85484495e-02, -2.52758134e-02,
#           5.88740110e-02,  1.29054459e-02,  1.03913143e-03,
#          -6.79576918e-02,  5.35328910e-02, -3.05745322e-02,
#          -1.84904356e-02, -2.76983809e-02,  1.21499170e-02,
#           2.81379651e-02,  2.19396316e-02,  2.33752672e-02,
#          -5.28661646e-02, -2.54432228e-03,  3.82954031e-02,
#           4.23453785e-02,  3.38966399e-02,  6.68702414e-03,
#          -8.90730470e-02, -7.54912794e-02, -9.44334716e-02,
#           6.75579458e-02, -7.01986626e-02,  3.54115255e-02,
#          -3.14607807e-02,  2.73347199e-02, -6.56227171e-02,
#           1.57458968e-02,  5.63005619e-02, -7.47876195e-03,
#          -5.19207492e-02, -3.83846718e-03, -2.01185420e-02,
#          -2.60216556e-02,  7.88303092e-02, -4.75525893e-02,
#           4.92555685e-02,  6.92525506e-02, -7.30518773e-02,
#           4.95599099e-02,  1.19920168e-02,  5.63893467e-02,
#          -2.14039143e-02,  2.01249048e-02, -1.66519620e-02,
#           3.27549912e-02,  2.94198170e-02,  3.53682563e-02,
#           3.93159594e-03,  1.92775770e-34,  6.14450239e-02,
#           1.71027798e-02,  8.47632065e-02,  3.57537121e-02,
#           5.06605618e-02,  9.16906595e-02, -5.65708289e-03,
#          -3.59039418e-02,  3.12043950e-02, -8.86430591e-02,
#          -3.52910571e-02, -1.01913996e-02, -6.92516491e-02,
#          -4.41775396e-02,  5.70497960e-02, -5.91539312e-04,
#          -6.87261298e-02,  6.19791783e-02,  3.05196103e-02,
#          -2.96812374e-02,  5.99694736e-02,  5.07950112e-02,
#          -8.22759233e-03,  2.14284845e-02,  2.27667093e-02,
#           9.28176716e-02,  5.77195846e-02, -8.81174430e-02,
#           7.71337748e-02,  2.55467203e-02, -9.97251645e-02,
#           2.06139907e-02, -6.11198023e-02,  7.27554709e-02,
#           4.79666442e-02,  4.65368293e-02, -2.15944499e-02,
#          -2.37565935e-02,  3.08040734e-02, -1.21315680e-02,
#           2.07918119e-02, -3.36557766e-03,  4.76241596e-02,
#          -8.39355960e-02, -7.49415383e-02,  1.24160051e-02,
#          -2.56413724e-02,  1.42461406e-02, -9.89642274e-03,
#           3.77713516e-02, -8.83727223e-02,  2.98517216e-02,
#          -5.54222800e-02,  1.44108627e-02,  8.01097136e-03,
#          -8.28111023e-02,  3.21905278e-02,  5.95116802e-02,
#          -1.79828680e-03,  5.88503927e-02,  1.93022955e-02,
#           8.00216664e-03, -5.17666247e-03,  1.84781775e-02,
#           1.73670985e-02,  1.11499824e-01, -1.02398545e-01,
#          -9.97240841e-03,  9.70465243e-02,  3.50963660e-02,
#           2.72321440e-02,  6.35505319e-02,  2.34845513e-03,
#           4.32579294e-02, -2.54202411e-02,  2.83132996e-02,
#          -1.21901296e-02, -8.55898336e-02,  4.08149026e-02,
#           3.19561698e-02, -7.61419535e-02, -3.52617465e-02,
#          -5.46798669e-02, -1.44773396e-02, -4.13271151e-02,
#          -1.21431537e-02, -1.23106251e-02, -2.46727411e-02,
#           1.39836399e-02,  2.05675606e-02, -8.64024907e-02,
#          -1.89582873e-02, -1.55371437e-02,  9.88751352e-02,
#          -2.24540252e-02, -4.63075622e-34, -3.63416262e-02,
#          -2.93962229e-02, -3.51123437e-02,  1.04702599e-01,
#           1.28976256e-02, -7.85095692e-02,  1.74482465e-02,
#           4.43763509e-02,  1.77052785e-02,  6.14803582e-02,
#           4.64209393e-02, -5.28656179e-03,  6.70333207e-02,
#           1.64294764e-02,  9.37129036e-02, -7.81316683e-02,
#           3.56947817e-02, -9.13436115e-02, -2.94126384e-02,
#           4.67076711e-02,  5.12748398e-02,  5.72793819e-02,
#          -1.55326441e-01, -3.51850763e-02,  6.05488233e-02,
#           1.73989702e-02,  1.83983650e-02, -2.48891604e-03,
#           1.70461442e-02, -4.95002568e-02, -9.99302231e-03,
#           4.54402268e-02, -8.91056731e-02,  2.43012942e-02,
#           1.32141737e-02,  7.95598924e-02,  1.09458372e-01,
#          -3.64047079e-03, -5.79992533e-02,  6.61877096e-02,
#           5.44871166e-02, -6.68147057e-02, -7.63909891e-02,
#           6.67296443e-03, -4.04000022e-02, -1.37276633e-03,
#          -5.56306206e-02,  8.62852558e-02, -5.01951501e-02,
#          -5.11408076e-02,  3.32711861e-02, -1.08650690e-02,
#          -1.33906938e-02, -6.36683255e-02, -7.16988668e-02,
#          -4.74443398e-02,  5.92492782e-02,  5.62706124e-03,
#          -4.50890511e-02, -6.40905788e-03, -3.04983649e-02,
#          -5.37575595e-02,  6.32176995e-02, -4.64570783e-02,
#           2.46379301e-02, -2.25161780e-02,  2.56019048e-02,
#           4.07071076e-02,  4.76768985e-02, -2.87892912e-02,
#          -4.31433469e-02, -7.93578774e-02, -1.10105993e-02,
#           6.44887611e-02,  4.20124270e-02,  5.19315004e-02,
#          -6.64633559e-03, -7.84371328e-03,  8.77366513e-02,
#          -5.85129224e-02,  1.61617734e-02, -1.99513920e-02,
#           7.19321519e-02,  3.21709141e-02,  1.02496922e-01,
#          -1.60838142e-02,  6.34673759e-02,  3.89562249e-02,
#           2.08782554e-02,  1.20483354e-01, -1.02373071e-01,
#           2.94305347e-02, -5.57659718e-04,  9.14123282e-02,
#          -7.78788328e-02, -1.59874496e-08, -8.26759264e-02,
#          -5.79014868e-02,  7.38885067e-03,  8.47869366e-02,
#           2.91340593e-02, -3.34376395e-02, -3.05022057e-02,
#           1.73821431e-02,  1.30569488e-02,  1.21622561e-02,
#           3.05456738e-03,  2.57679704e-03, -3.90552357e-02,
#          -2.88580135e-02,  2.10515801e-02,  2.70685498e-02,
#          -3.02647408e-02, -1.40017197e-02,  1.01363482e-02,
#          -1.03471272e-01,  6.03960901e-02, -3.07124853e-02,
#          -2.39386223e-03,  1.36913667e-02, -2.39641666e-02,
#          -8.38653147e-02, -2.04173326e-02,  5.28004989e-02,
#          -4.60236222e-02,  7.18137771e-02,  1.16663966e-02,
#           2.20560329e-03,  2.38147117e-02, -2.13163923e-02,
#           3.52246501e-02,  4.40341011e-02,  2.24671680e-02,
#          -1.65044032e-02,  1.55876707e-02,  9.67702176e-03,
#          -3.50403525e-02, -1.56284161e-02, -5.76556548e-02,
#          -2.07515154e-02,  5.15925847e-02,  2.75106207e-02,
#          -7.50161856e-02, -1.72331914e-01,  3.57183777e-02,
#          -3.65126766e-02, -9.25954804e-02,  6.99149678e-03,
#           1.25614824e-02,  3.57152596e-02,  6.89837262e-02,
#           2.09128167e-02,  1.44317243e-02, -4.27332036e-02,
#          -2.88078003e-02,  5.55539913e-02, -2.89376895e-03,
#           4.35364768e-02, -1.32396389e-02,  3.21107334e-03]]),
#  'documents': ['Claude 4.5 is latest conversational AI model from Anthropic.',
#   'GPT-5 is latest conversational AI model from OpenAI'],
#  'uris': None,
#  'included': ['embeddings', 'documents'],
#  'data': None,
#  'metadatas': None}

# %%
len(result['embeddings'][0])
# Out:
# 384

# %%
result = collection.peek(limit=3)

# %%
result
# Out:
# {'ids': ['anthropic', 'google', 'meta'],
#  'embeddings': array([[ 0.00884438, -0.01740049,  0.00039467, ...,  0.06249589,
#          -0.03616665, -0.05505916],
#         [-0.08895399, -0.09540191,  0.02952658, ...,  0.07311269,
#          -0.01206857, -0.03972095],
#         [ 0.00442572, -0.04778809, -0.0161633 , ...,  0.07723493,
#          -0.03395461, -0.00226511]], shape=(3, 384)),
#  'documents': ['Claude 4.5 is latest conversational AI model from Anthropic.',
#   'Gemini is latest conversational AI model from google.',
#   'Llama-4 is latest conversational AI model from Meta.'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'version': 4.5}, {'version': 3}, {'version': 4}]}

# %% [markdown]
# ## Query vector store | Search relevent Documents
#
# ### 4.1 Search relevant documents
# * query_texts - Query based on text
# * query_embeddings - Query based on embeddings value
#
# Default distance metric is I2 or euclidean which means low score is near to query

# %%
from pprint import pprint

results = collection.query(
    query_texts=["Which is the latest AI model from Anthropic?",], # chroma will embed this for us using embedding_function
    n_results=3
)

pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.5319048166275024, 0.9215655326843262, 0.9596002101898193]],
#  'documents': [['Claude 4.5 is latest conversational AI model from Anthropic.',
#                 'Mixtral 8x7B is latest conversational AI model from Mistral '
#                 'AI.',
#                 'Llama-4 is latest conversational AI model from Meta.']],
#  'embeddings': None,
#  'ids': [['anthropic', 'mistral', 'meta']],
#  'included': ['metadatas', 'documents', 'distances'],
#  'metadatas': [[{'version': 4.5}, {'version': 2}, {'version': 4}]],
#  'uris': None}

# %%
results['documents']
# Out:
# [['Claude 4.5 is latest conversational AI model from Anthropic.',
#   'Mixtral 8x7B is latest conversational AI model from Mistral AI.',
#   'Llama-4 is latest conversational AI model from Meta.']]

# %% [markdown]
# * include() : what fields to include in result. Default is ["Metadatas", "documents", "distances"]

# %%
results = collection.query(
    query_texts= ["Which is the latest AI model from Anthropic?"],
    n_results= 3,
    include=['embeddings', 'documents', 'distances']
)

pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.5319048166275024, 0.9215655326843262, 0.9596002101898193]],
#  'documents': [['Claude 4.5 is latest conversational AI model from Anthropic.',
#                 'Mixtral 8x7B is latest conversational AI model from Mistral '
#                 'AI.',
#                 'Llama-4 is latest conversational AI model from Meta.']],
#  'embeddings': [array([[ 0.00884438, -0.01740049,  0.00039467, ...,  0.06249589,
#         -0.03616665, -0.05505916],
#        [-0.03611682, -0.08049719,  0.03304322, ..., -0.02273243,
#         -0.01788436,  0.00234854],
#        [ 0.00442572, -0.04778809, -0.0161633 , ...,  0.07723493,
#         -0.03395461, -0.00226511]], shape=(3, 384))],
#  'ids': [['anthropic', 'mistral', 'meta']],
#  'included': ['embeddings', 'documents', 'distances'],
#  'metadatas': None,
#  'uris': None}

# %% [markdown]
# ### Filter Documents using "where" and "where_documents" clause
#
# Both clauses are supported in query(), get() and  delete() methods of collection
#
# #### "where" clause
# Filtering metadata supports the follwing operators:
#
# * $eq - equal to (string, int, float)
# * $ne - not equal to (string, int, float)
# * $gt - greater than (int, float)
# * $gte - greater than or equal to (int, float)
# * $lt - less than (int, float)
# * $lte - less than or equal to (int, float)

# %%
results = collection.query(
    query_texts= ["Which is the latest AI model from Anthropic?"],
    n_results= 3,
    where={"version": {"$eq": 4.5}}
)

pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.5319048166275024, 0.9596002101898193]],
#  'documents': [['Claude 4.5 is latest conversational AI model from Anthropic.',
#                 'Llama-4 is latest conversational AI model from Meta.']],
#  'embeddings': None,
#  'ids': [['anthropic', 'meta']],
#  'included': ['metadatas', 'documents', 'distances'],
#  'metadatas': [[{'version': 4.5}, {'version': 4}]],
#  'uris': None}

# %%
results = collection.query(
    query_texts= ["Which is the latest AI model from Anthropic?"],
    n_results= 3,
    where={"version": {"$gt": 3}}
)

pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.5319048166275024, 0.9596002101898193, 1.0497297048568726]],
#  'documents': [['Claude 4.5 is latest conversational AI model from Anthropic.',
#                 'Llama-4 is latest conversational AI model from Meta.',
#                 'GPT-5 is latest conversational AI model from OpenAI']],
#  'embeddings': None,
#  'ids': [['anthropic', 'meta', 'openai']],
#  'included': ['metadatas', 'documents', 'distances'],
#  'metadatas': [[{'version': 4.5}, {'version': 4}, {'version': 5}]],
#  'uris': None}

# %% [markdown]
# * The follwing inclusion operators are supported
#
# * $in - a value is in predefined list (string, int, float, bool)
# * $nin - value is not in predefined list (string, int, float, bool)

# %%
results = collection.query(
    query_texts= ["Which is the latest AI model from Anthropic?"],
    n_results= 3,
    where={"version": {"$in": [3, 4]}}
)

pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.9596002101898193, 0.999941349029541]],
#  'documents': [['Llama-4 is latest conversational AI model from Meta.',
#                 'Gemini is latest conversational AI model from google.']],
#  'embeddings': None,
#  'ids': [['meta', 'google']],
#  'included': ['metadatas', 'documents', 'distances'],
#  'metadatas': [[{'version': 4}, {'version': 3}]],
#  'uris': None}
